# %% [markdown]
# ## Download the text doc

# %% [markdown]
# #### file -> spp.docx, course.pdf
# #### https://mitu.co.in/dataset

# %%
# with open('SMSSpamCollection', 'r') as f:
#     text_sms = f.readlines()
# text_sms

# %%
import pandas as pd
from sklearn.svm import SVC
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize import word_tokenize
import pandas as pd
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV, KFold
from sklearn.metrics import classification_report, accuracy_score, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import seaborn as sns

sms_df = pd.read_csv('SMSSpamCollection.csv', sep='\t' , names=['label', 'message'])
# sms_df = pd.DataFrame(data=text_sms, columns=['text'])
sms_df
# Out:
#      label                                            message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
# # splitting labels and messages from main text using \t as the delimiter 
# sms_df['label'] = sms_df['text'].str.split('\t').str[0]
# sms_df['message'] = sms_df['text'].str.split('\t').str[1].str.strip()
# sms_df.drop(columns=['text'], inplace=True)
# sms_df

# %%
# Explore the data
X = sms_df['message']
y = sms_df['label']
X
# Out:
# 0       Go until jurong point, crazy.. Available only ...
# 1                           Ok lar... Joking wif u oni...
# 2       Free entry in 2 a wkly comp to win FA Cup fina...
# 3       U dun say so early hor... U c already then say...
# 4       Nah I don't think he goes to usf, he lives aro...
#                               ...
# 5567    This is the 2nd time we have tried 2 contact u...
# 5568                 Will ü b going to esplanade fr home?
# 5569    Pity, * was in mood for that. So...any other s...
# 5570    The guy did some bitching but I acted like i'd...
# 5571                           Rofl. Its true to its name
# Name: message, Length: 5572, dtype: object

# %%
y
# Out:
# 0        ham
# 1        ham
# 2       spam
# 3        ham
# 4        ham
#         ...
# 5567    spam
# 5568     ham
# 5569     ham
# 5570     ham
# 5571     ham
# Name: label, Length: 5572, dtype: object

# %%
# value counts of y
value_df = y.value_counts()
sns.barplot([value_df['ham'], value_df['spam']]) # checking for the disparity between the classfied labels
# Out:
# <Axes: >

# %%
plt.pie(value_df, labels=value_df.index, autopct='%2.2f%%') # pie chart visualization
# Out:
# ([<matplotlib.patches.Wedge at 0x2875d462a50>,
#   <matplotlib.patches.Wedge at 0x2875d0c58e0>],
#  [Text(-1.0038714981945518, 0.4497132587689916, 'ham'),
#   Text(1.0038714771419537, -0.44971330576360763, 'spam')],
#  [Text(-0.5475662717424827, 0.24529814114672266, '86.59%'),
#   Text(0.5475662602592474, -0.2452981667801496, '13.41%')])

# %%
# pip install wordcloud pillow -U

# %%
# trying to store all 'ham' messages in a single string, same with spam. Creation of two different wordclouds
ham = X[y=='ham']
display(ham)
len(ham)
# Out:
# 0       Go until jurong point, crazy.. Available only ...
# 1                           Ok lar... Joking wif u oni...
# 3       U dun say so early hor... U c already then say...
# 4       Nah I don't think he goes to usf, he lives aro...
# 6       Even my brother is not like to speak with me. ...
#                               ...
# 5565                                         Huh y lei...
# 5568                 Will ü b going to esplanade fr home?
# 5569    Pity, * was in mood for that. So...any other s...
# 5570    The guy did some bitching but I acted like i'd...
# 5571                           Rofl. Its true to its name
# Name: message, Length: 4825, dtype: object
# 4825

# %%
# for spam
spam = X[y=='spam']
display(spam)
len(spam)
# Out:
# 2       Free entry in 2 a wkly comp to win FA Cup fina...
# 5       FreeMsg Hey there darling it's been 3 week's n...
# 8       WINNER!! As a valued network customer you have...
# 9       Had your mobile 11 months or more? U R entitle...
# 11      SIX chances to win CASH! From 100 to 20,000 po...
#                               ...
# 5537    Want explicit SEX in 30 secs? Ring 02073162414...
# 5540    ASKED 3MOBILE IF 0870 CHATLINES INCLU IN FREE ...
# 5547    Had your contract mobile 11 Mnths? Latest Moto...
# 5566    REMINDER FROM O2: To get 2.50 pounds free call...
# 5567    This is the 2nd time we have tried 2 contact u...
# Name: message, Length: 747, dtype: object
# 747

# %%
# making a single string store all the messages of ham and another one for spam
ham_str = ' '.join(ham)
spam_str = ' '.join(spam)
len(ham_str)
# Out:
# 349727

# %%
len(spam_str)
# Out:
# 104333

# %%
# importing wordcloud
from wordcloud import WordCloud

# %%
# finding a system font path
from matplotlib import font_manager

# Find a system font path
font_path = font_manager.findfont('MonoLisa')
# Out:
# findfont: Font family ['MonoLisa'] not found. Falling back to DejaVu Sans.

# %%
# Not spam (ham) wordcloud
wc_notspam = WordCloud(font_path=font_path, background_color='white', max_words=1000).generate(ham_str)
# the above variable will be passed to imshow, since the wordcloud has been created and now needs to be displayed
plt.figure(figsize=(10,5))
plt.imshow(wc_notspam, interpolation='bilinear')
plt.axis(False)
plt.show()

# %%
wc_notspam.words_
# Out:
# {'u': 1.0,
#  'will': 0.33096446700507615,
#  'lt gt': 0.2802030456852792,
#  'Ok': 0.2649746192893401,
#  'now': 0.2578680203045685,
#  'go': 0.25583756345177666,
#  'got': 0.2365482233502538,
#  'know': 0.2182741116751269,
#  'come': 0.21116751269035533,
#  'call': 0.20812182741116753,
#  'love': 0.20609137055837565,
#  'time': 0.20101522842639594,
#  'ur': 0.19898477157360406,
#  'day': 0.18883248730964466,
#  'want': 0.18781725888324874,
#  'one': 0.17766497461928935,
#  'need': 0.17563451776649747,
#  'going': 0.1715736040609137,
#  'good': 0.166497461928934,
#  'Sorry': 0.15939086294416244,
#  'ü': 0.15634517766497463,
#  'home': 0.15532994923857868,
#  'still': 0.1532994923857868,
#  'da': 0.14416243654822336,
#  'see': 0.14213197969543148,
#  'today': 0.1401015228426396,
#  'think': 0.13401015228426397,
#  'n': 0.132994923857868,
#  'lor': 0.12791878172588833,
#  'tell': 0.12690355329949238,
#  'dont': 0.12284263959390863,
#  'say': 0.12081218274111676,
#  'back': 0.12081218274111676,
#  'Oh': 0.11573604060913706,
#  'thing': 0.11472081218274112,
#  'much': 0.11370558375634518,
#  'hope': 0.11269035532994924,
#  'well': 0.11065989847715736,
#  'Hey': 0.10862944162436548,
#  'send': 0.1065989847715736,
#  'work': 0.10558375634517767,
#  'make': 0.10456852791878173,
#  'way': 0.10253807106598985,
#  'give': 0.10253807106598985,
#  'take': 0.10152284263959391,
#  'dear': 0.10050761421319797,
#  'let': 0.09340101522842639,
#  'ask': 0.09238578680203045,
#  'already': 0.09137055837563451,
#  'Thank': 0.09137055837563451,
#  'later': 0.09035532994923857,
#  'wat': 0.08934010152284264,
#  'Yeah': 0.08730964467005076,
#  'really': 0.08629441624365482,
#  'e': 0.08527918781725888,
#  'd': 0.08527918781725888,
#  'great': 0.08426395939086294,
#  'changed': 0.006091370558375634,
#  'directly': 0.006091370558375634,
#  'qatar': 0.006091370558375634,
#  'spoke': 0.006091370558375634,
#  'gr8': 0.006091370558375634,
#  'bye': 0.006091370558375634,
#  'joined': 0.006091370558375634,
#  'connection': 0.006091370558375634,
#  'correct': 0.006091370558375634,
#  'dint': 0.006091370558375634,
#  'ended': 0.006091370558375634,
#  'definitely': 0.006091370558375634,
#  'anybody': 0.006091370558375634,
#  'sign': 0.006091370558375634,
#  'track': 0.006091370558375634,
#  'read': 0.006091370558375634,
#  'report': 0.006091370558375634,
#  'wiv': 0.006091370558375634,
#  'num': 0.006091370558375634,
#  'posted': 0.006091370558375634,
#  'air': 0.006091370558375634,
#  'body': 0.006091370558375634,
#  'guide': 0.006091370558375634,
#  'relax': 0.006091370558375634,
#  'pilates': 0.006091370558375634,
#  'putting': 0.006091370558375634,
#  'aathi': 0.006091370558375634,
#  'wnt': 0.006091370558375634,
#  'askin': 0.006091370558375634,
#  'group': 0.006091370558375634,
#  'result': 0.006091370558375634,
#  'Ttyl': 0.006091370558375634,
#  'isnt': 0.006091370558375634,
#  'fb': 0.006091370558375634,
#  'fixed': 0.006091370558375634,
#  'less': 0.006091370558375634,
#  'campus': 0.006091370558375634,
#  'lady': 0.006091370558375634,
#  'Hurry': 0.006091370558375634,
#  'cheap': 0.006091370558375634,
#  'Aiyo': 0.006091370558375634,
#  'scream': 0.006091370558375634,
#  'alex': 0.006091370558375634}

# %%
# Spam wordcloud
wc_spam = WordCloud(font_path=font_path, background_color='white', max_words=1000).generate(spam_str)
# the above variable will be passed to imshow, since the wordcloud has been created and now needs to be displayed
plt.figure(figsize=(10,5))
plt.imshow(wc_spam, interpolation='bilinear')
plt.axis(False)
plt.show()

# %%
wc_spam.words_
# Out:
# {'FREE': 1.0,
#  'call': 0.875,
#  'text': 0.63,
#  'U': 0.59,
#  'txt': 0.5,
#  'now': 0.5,
#  'mobile': 0.5,
#  'won': 0.365,
#  'T C': 0.33,
#  'claim': 0.315,
#  'STOP': 0.315,
#  'reply': 0.31,
#  'prize': 0.305,
#  'call now': 0.29,
#  'URGENT': 0.28,
#  'win': 0.27,
#  'new': 0.27,
#  'tone': 0.265,
#  'co uk': 0.245,
#  '150p': 0.24,
#  'Please call': 0.23,
#  'will': 0.22,
#  'message': 0.21,
#  'chat': 0.2,
#  'ringtone': 0.18,
#  'cash': 0.17,
#  'receive': 0.165,
#  'send': 0.145,
#  'award': 0.14,
#  'want': 0.135,
#  'poly': 0.135,
#  'customer service': 0.135,
#  'PO Box': 0.135,
#  'contact U': 0.135,
#  'msg': 0.125,
#  'go': 0.125,
#  'SMS': 0.12,
#  'landline': 0.12,
#  '150ppm': 0.115,
#  'find': 0.115,
#  'collect': 0.115,
#  'phone': 0.115,
#  'GUARANTEED Call': 0.115,
#  'day': 0.11,
#  'uk': 0.11,
#  'offer': 0.11,
#  'chance': 0.11,
#  'prize GUARANTEED': 0.11,
#  'contact': 0.105,
#  'pic': 0.105,
#  'week': 0.1,
#  'customer': 0.1,
#  'send STOP': 0.1,
#  'national rate': 0.1,
#  'back': 0.095,
#  'ur': 0.095,
#  'awarded': 0.095,
#  'See': 0.095,
#  'Club': 0.095,
#  'Orange': 0.095,
#  'every week': 0.095,
#  'await collection': 0.095,
#  'PRIVATE': 0.09,
#  'Hi': 0.09,
#  'game': 0.09,
#  'land line': 0.09,
#  'selected': 0.085,
#  'latest': 0.085,
#  'tried': 0.085,
#  'Nokia': 0.085,
#  'end': 0.085,
#  'opt': 0.085,
#  'Valid 12hrs': 0.085,
#  'winner': 0.08,
#  'next': 0.08,
#  'know': 0.08,
#  'join': 0.08,
#  'Thank': 0.08,
#  'auction': 0.08,
#  'Free entry': 0.08,
#  'Account Statement': 0.08,
#  'Call Identifier': 0.08,
#  'Identifier Code': 0.08,
#  '150p msg': 0.08,
#  'Call MobileUpd8': 0.08,
#  'service': 0.075,
#  'trying': 0.075,
#  'sexy': 0.075,
#  'name': 0.075,
#  'number': 0.075,
#  'Xmas': 0.075,
#  '1st': 0.075,
#  'B': 0.075,
#  'draw shows': 0.075,
#  'ur mob': 0.075,
#  'Suite342 2Lands': 0.075,
#  '2Lands Row': 0.075,
#  'txt STOP': 0.075,
#  'dating service': 0.075,
#  'Update': 0.07,
#  'info': 0.07,
#  'yr': 0.07,
#  'content': 0.07,
#  'someone': 0.07,
#  'unsubscribe': 0.07,
#  'pound': 0.07,
#  'ur awarded': 0.07,
#  'Code Expires': 0.07,
#  'line Claim': 0.07,
#  '2nd attempt': 0.07,
#  'tell ur': 0.07,
#  'question': 0.065,
#  'word': 0.065,
#  'credit': 0.065,
#  'year': 0.065,
#  'min': 0.065,
#  'time': 0.065,
#  'txt NOKIA': 0.065,
#  'camera phone': 0.065,
#  'ur cash': 0.065,
#  'Claim ur': 0.065,
#  'gift voucher': 0.065,
#  'charged': 0.06,
#  're': 0.06,
#  'waiting': 0.06,
#  'top': 0.06,
#  'date': 0.06,
#  'reveal': 0.06,
#  'call2optout': 0.06,
#  'Claim code': 0.06,
#  'SMS ac': 0.06,
#  'guaranteed cash': 0.06,
#  'Caller Prize': 0.06,
#  'Camcorder Reply': 0.06,
#  'Double Mins': 0.06,
#  'Half Price': 0.06,
#  'shows un': 0.06,
#  'un redeemed': 0.06,
#  'redeemed S': 0.06,
#  'M points': 0.06,
#  'points Call': 0.06,
#  'every wk': 0.06,
#  'Nokia tone': 0.06,
#  'ur mates': 0.06,
#  'per min': 0.06,
#  'std': 0.055,
#  'FreeMsg': 0.055,
#  'XXX': 0.055,
#  'valued': 0.055,
#  'reward': 0.055,
#  'WAP': 0.055,
#  'eg': 0.055,
#  'month': 0.055,
#  'F': 0.055,
#  'Today': 0.055,
#  'weekly': 0.055,
#  'X': 0.055,
#  'sex': 0.055,
#  'Enjoy': 0.055,
#  'great': 0.055,
#  'C apply': 0.055,
#  'Bonus Caller': 0.055,
#  'reply STOP': 0.055,
#  'now send': 0.055,
#  'HG Suite342': 0.055,
#  'Row W1J6HL': 0.055,
#  'line rental': 0.055,
#  'Mobile number': 0.055,
#  '1st week': 0.055,
#  'tone ur': 0.055,
#  'BT national': 0.055,
#  'entry': 0.05,
#  'Holiday': 0.05,
#  'txting': 0.05,
#  'friend': 0.05,
#  'hot': 0.05,
#  'Choose': 0.05,
#  'easy': 0.05,
#  'love': 0.05,
#  'Dear': 0.05,
#  'one': 0.05,
#  'Wanna': 0.05,
#  'babe': 0.05,
#  'enter': 0.05,
#  'service representative': 0.05,
#  'live operator': 0.05,
#  'u know': 0.05,
#  'secret admirer': 0.05,
#  'special call': 0.05,
#  'new video': 0.05,
#  'video phone': 0.05,
#  'Ts Cs': 0.05,
#  'wk TXT': 0.05,
#  'getzed co': 0.05,
#  'network mins': 0.05,
#  'cash await': 0.05,
#  'SAE T': 0.05,
#  '10p min': 0.05,
#  'fun': 0.045,
#  'use': 0.045,
#  'ENGLAND': 0.045,
#  'live': 0.045,
#  'AGE': 0.045,
#  'tv': 0.045,
#  'take': 0.045,
#  'Fancy': 0.045,
#  'Bluetooth': 0.045,
#  'help': 0.045,
#  'SHOP': 0.045,
#  'girl': 0.045,
#  'draw txt': 0.045,
#  'txt MUSIC': 0.045,
#  'Text YES': 0.045,
#  'U Todays': 0.045,
#  'Todays draw': 0.045,
#  'mob every': 0.045,
#  'take part': 0.045,
#  'entitled': 0.04,
#  'play': 0.04,
#  'real': 0.04,
#  'FREEPHONE': 0.04,
#  'meet': 0.04,
#  'CD': 0.04,
#  'video': 0.04,
#  'anytime': 0.04,
#  'first': 0.04,
#  '50p': 0.04,
#  'area': 0.04,
#  '25p': 0.04,
#  'matches': 0.04,
#  'STORE': 0.04,
#  'bid': 0.04,
#  'need': 0.04,
#  'details': 0.04,
#  'TnC': 0.04,
#  'latest colour': 0.04,
#  'free camcorder': 0.04,
#  'ip4 5we': 0.04,
#  'specially selected': 0.04,
#  'numbers ending': 0.04,
#  'looking make': 0.04,
#  'make contact': 0.04,
#  'U find': 0.04,
#  'thinks UR': 0.04,
#  'per week': 0.04,
#  'Claim Valid': 0.04,
#  'Txt word': 0.04,
#  'offers mobile': 0.04,
#  'collection SAE': 0.04,
#  'Digital Camera': 0.04,
#  'Ltd PO': 0.04,
#  'New Nokia': 0.04,
#  '10p per': 0.04,
#  'C': 0.035,
#  'apply': 0.035,
#  'still': 0.035,
#  'Cost': 0.035,
#  'Try': 0.035,
#  'Bonus': 0.035,
#  'Last': 0.035,
#  'start': 0.035,
#  'Congratulations': 0.035,
#  'horny': 0.035,
#  'HMV': 0.035,
#  'sport': 0.035,
#  'access': 0.035,
#  'visit': 0.035,
#  'Sub': 0.035,
#  'Unsub': 0.035,
#  'Gr8': 0.035,
#  'O2': 0.035,
#  'got': 0.035,
#  'plus': 0.035,
#  'Im': 0.035,
#  'Saturday': 0.035,
#  'term': 0.035,
#  'night': 0.035,
#  'delivery tomorrow': 0.035,
#  'bx420 ip4': 0.035,
#  'per msg': 0.035,
#  'Reply YES': 0.035,
#  'Congratulations ur': 0.035,
#  'per minute': 0.035,
#  'cash balance': 0.035,
#  'maximize ur': 0.035,
#  'Tenerife Holiday': 0.035,
#  'ur worth': 0.035,
#  'discount vouchers': 0.035,
#  'now SavaMob': 0.035,
#  'Shopping spree': 0.035,
#  'Cs apply': 0.035,
#  'week No1': 0.035,
#  'No1 Nokia': 0.035,
#  'weekly draw': 0.035,
#  'price line': 0.035,
#  'chance win': 0.035,
#  'log onto': 0.035,
#  'W1J6HL LDN': 0.035,
#  '20p per': 0.035,
#  'min NTT': 0.035,
#  'NTT Ltd': 0.035,
#  'Box Croydon': 0.035,
#  'Croydon CR9': 0.035,
#  'CR9 5WB': 0.035,
#  'Urgent Please': 0.035,
#  'Costa Del': 0.035,
#  'Del Sol': 0.035,
#  'Sol Holiday': 0.035,
#  'final': 0.03,
#  'link': 0.03,
#  'subscription': 0.03,
#  'replying': 0.03,
#  'special': 0.03,
#  'speak': 0.03,
#  'Quiz': 0.03,
#  'inviting': 0.03,
#  'download': 0.03,
#  'wk': 0.03,
#  'keep': 0.03,
#  'think': 0.03,
#  'Double': 0.03,
#  'calling': 0.03,
#  'entered': 0.03,
#  'vary': 0.03,
#  'Welcome': 0.03,
#  'worth': 0.03,
#  'important': 0.03,
#  'guys': 0.03,
#  'Vodafone': 0.03,
#  'PC': 0.03,
#  'b4': 0.03,
#  'TXTAUCTION': 0.03,
#  'Summer': 0.03,
#  'Good': 0.03,
#  'charity': 0.03,
#  'asked': 0.03,
#  'urawinner': 0.03,
#  'fone': 0.03,
#  'single': 0.03,
#  'reply HL': 0.03,
#  'dont miss': 0.03,
#  'friend Reply': 0.03,
#  'ac u': 0.03,
#  'STOP FRND': 0.03,
#  'mobile 11mths': 0.03,
#  'colour camera': 0.03,
#  'send GO': 0.03,
#  'msg rcvd': 0.03,
#  'currently pounds': 0.03,
#  'Latest Motorola': 0.03,
#  'ringtone order': 0.03,
#  'latest camera': 0.03,
#  '40GB iPod': 0.03,
#  'SavaMob member': 0.03,
#  'member offers': 0.03,
#  'service announcement': 0.03,
#  'Dear Voucher': 0.03,
#  'Voucher Holder': 0.03,
#  'uk POBox': 0.03,
#  'POBox W45WQ': 0.03,
#  'W45WQ norm150p': 0.03,
#  'norm150p tone': 0.03,
#  'final attempt': 0.03,
#  'SiPix Digital': 0.03,
#  'landline Delivery': 0.03,
#  'Delivery within': 0.03,
#  'Important information': 0.03,
#  'lucky day': 0.03,
#  'Good Luck': 0.03,
#  'weekly comp': 0.03,
#  'FANTASIES call': 0.03,
#  '2nd time': 0.03,
#  'Now toClaim': 0.03,
#  'toClaim SAE': 0.03,
#  'POBox334 Stockport': 0.03,
#  'Stockport SK38xh': 0.03,
#  'SK38xh Cost': 0.03,
#  'Cost pm': 0.03,
#  'pm Max10mins': 0.03,
#  'SAE TC': 0.03,
#  'Orange tariffs': 0.03,
#  'Last weekend': 0.03,
#  'may': 0.025,
#  'ok': 0.025,
#  'network': 0.025,
#  'net': 0.025,
#  'click': 0.025,
#  'YES': 0.025,
#  'Congrats': 0.025,
#  'direct': 0.025,
#  'MUST': 0.025,
#  'local': 0.025,
#  'Luv': 0.025,
#  'partner': 0.025,
#  'e': 0.025,
#  'G': 0.025,
#  'Ldew': 0.025,
#  'answer': 0.025,
#  'TheMob': 0.025,
#  'selection': 0.025,
#  'December': 0.025,
#  'custcare': 0.025,
#  'true': 0.025,
#  'contacted': 0.025,
#  'Loan': 0.025,
#  'Activate': 0.025,
#  'come': 0.025,
#  'voucher': 0.025,
#  'best': 0.025,
#  'POLYPHONIC': 0.025,
#  'either': 0.025,
#  'talk': 0.025,
#  'give': 0.025,
#  'revealed': 0.025,
#  'invited': 0.025,
#  'XCHAT': 0.025,
#  'p': 0.025,
#  'subscriber': 0.025,
#  'place': 0.025,
#  'let': 0.025,
#  'OptOut': 0.025,
#  'reach': 0.025,
#  'eerie': 0.025,
#  'rply': 0.025,
#  'alert': 0.025,
#  'computer': 0.025,
#  'mth': 0.025,
#  'official': 0.025,
#  'flag': 0.025,
#  'cancel': 0.025,
#  'm8': 0.025,
#  'Update Co': 0.025,
#  '5we 150pm': 0.025,
#  'weekends draw': 0.025,
#  'Todays Voda': 0.025,
#  'Voda numbers': 0.025,
#  'match please': 0.025,
#  'call quoting': 0.025,
#  'quoting claim': 0.025,
#  'code standard': 0.025,
#  'standard rates': 0.025,
#  'Sunshine Quiz': 0.025,
#  'Sony DVD': 0.025,
#  'sent direct': 0.025,
#  'e g': 0.025,
#  'Video Handset': 0.025,
#  'mins UNLIMITED': 0.025,
#  'UNLIMITED TEXT': 0.025,
#  'msg CC': 0.025,
#  'Cost 150ppm': 0.025,
#  'iPod MP3': 0.025,
#  'MP3 player': 0.025,
#  'custcare 1x150p': 0.025,
#  '1x150p wk': 0.025,
#  'CALL immediately': 0.025,
#  'message waiting': 0.025,
#  '7pm Cost': 0.025,
#  'Cost 10p': 0.025,
#  'awarded either': 0.025,
#  'CD gift': 0.025,
#  'credits pls': 0.025,
#  'comuk net': 0.025,
#  'net login': 0.025,
#  'extra charge': 0.025,
#  'charge help': 0.025,
#  'mins Half': 0.025,
#  'Congrats mobile': 0.025,
#  'mobile 3G': 0.025,
#  '3G Videophones': 0.025,
#  'now videochat': 0.025,
#  'videochat wid': 0.025,
#  'mates play': 0.025,
#  'play java': 0.025,
#  'java games': 0.025,
#  'games Dload': 0.025,
#  'music noline': 0.025,
#  'noline rentl': 0.025,
#  'FANTASTIC SURPRISE': 0.025,
#  'SURPRISE AWAITING': 0.025,
#  'network operator': 0.025,
#  'rates apply': 0.025,
#  'HOT LIVE': 0.025,
#  'LIVE FANTASIES': 0.025,
#  'part send': 0.025,
#  '60p min': 0.025,
#  'arrive please': 0.025,
#  'minute BT': 0.025,
#  'logo pic': 0.025,
#  'Nokia 3510i': 0.025,
#  '3510i colour': 0.025,
#  'colour phone': 0.025,
#  'FA': 0.02,
#  'POBox': 0.02,
#  'etc': 0.02,
#  'trip': 0.02,
#  'country': 0.02,
#  'SP': 0.02,
#  'laid': 0.02,
#  'tonight': 0.02,
#  'nothing': 0.02,
#  'order': 0.02,
#  'even': 0.02,
#  'flirt': 0.02,
#  'recd': 0.02,
#  'MUSIC': 0.02,
#  '4u': 0.02,
#  'M': 0.02,
#  'Check': 0.02,
#  'currently': 0.02,
#  'logo': 0.02,
#  '3mins': 0.02,
#  'Close': 0.02,
#  'Mtmsgrcvd18': 0.02,
#  'PARIS': 0.02,
#  'Hello': 0.02,
#  'Forwarded': 0.02,
#  'Book': 0.02,
#  'tell': 0.02,
#  'Remove': 0.02,
#  'ppm': 0.02,
#  'VIP': 0.02,
#  'user': 0.02,
#  'Sale': 0.02,
#  'cheap': 0.02,
#  'money': 0.02,
#  'getting': 0.02,
#  'contract': 0.02,
#  'registered': 0.02,
#  'future': 0.02,
#  'ready': 0.02,
#  'Lucozade': 0.02,
#  'Jordan': 0.02,
#  'delivered': 0.02,
#  'xx': 0.02,
#  'jamster': 0.02,
#  'TEXTPOD': 0.02,
#  '2nite': 0.02,
#  'hope': 0.02,
#  '2day': 0.02,
#  'TITLE': 0.02,
#  'ACTION': 0.02,
#  'GOING': 0.02,
#  'Arcade': 0.02,
#  'exciting': 0.02,
#  'FREEFONE': 0.02,
#  'PIX': 0.02,
#  'adult': 0.02,
#  'hit': 0.02,
#  'show': 0.02,
#  'PORN': 0.02,
#  'Bloomberg': 0.02,
#  'film': 0.02,
#  'Santa': 0.02,
#  'ticket': 0.02,
#  'goal': 0.02,
#  'wkly comp': 0.02,
#  'Cup final': 0.02,
#  'holiday flights': 0.02,
#  'flights inc': 0.02,
#  'inc speak': 0.02,
#  'shows unredeemed': 0.02,
#  'rates app': 0.02,
#  'Quiz Wkly': 0.02,
#  'Wkly Q': 0.02,
#  'Q Win': 0.02,
#  'top Sony': 0.02,
#  'DVD player': 0.02,
#  'Txt ansr': 0.02,
#  'SP Tyrone': 0.02,
#  'Want real': 0.02,
#  'locations sent': 0.02,
#  'largest Dogging': 0.02,
#  'Dogging Network': 0.02,
#  '9am 11pm': 0.02,
#  'Ldew com1win150ppmx3age16': 0.02,
#  'Handset anytime': 0.02,
#  'Motorola SonyEricsson': 0.02,
#  'SonyEricsson Nokia': 0.02,
#  'order reference': 0.02,
#  'price Orange': 0.02,
#  'Tenants welcome': 0.02,
#  "back help'": 0.02,
#  '10am 7pm': 0.02,
#  'Customer Loyalty': 0.02,
#  'Loyalty Offer': 0.02,
#  'word START': 0.02,
#  'Now 4T': 0.02,
#  'spree every': 0.02,
#  'SavaMob POBOX84': 0.02,
#  'POBOX84 M263UZ': 0.02,
#  'M263UZ Sub': 0.02,
#  'pls goto': 0.02,
#  'login 3qxj9': 0.02,
#  '3qxj9 unsubscribe': 0.02,
#  'help COMUK': 0.02,
#  'Ibiza Holiday': 0.02,
#  'Gay chat': 0.02,
#  'Cant Guess': 0.02,
#  'user Today': 0.02,
#  'txtin now': 0.02,
#  'HL 4info': 0.02,
#  'original n': 0.02,
#  'n best': 0.02,
#  'Tones 3GBP': 0.02,
#  '3GBP network': 0.02,
#  '150p MsgrcvdHG': 0.02,
#  'MsgrcvdHG Suite342': 0.02,
#  'Txt POD': 0.02,
#  'brand new': 0.02,
#  'Nokia 7250i': 0.02,
#  'Row W1JHL': 0.02,
#  'WELL DONE': 0.02,
#  'week starting': 0.02,
#  'starting NOW': 0.02,
#  'colour flag': 0.02,
#  'yer mobile': 0.02,
#  'txt ENG': 0.02,
#  'ENG STOP': 0.02,
#  'STOP Box39822': 0.02,
#  'Box39822 W111WX': 0.02,
#  'inclusive text': 0.02,
#  'TC s': 0.02,
#  's POBox334': 0.02,
#  'wid ur': 0.02,
#  'rentl bx420': 0.02,
#  'fromm landline': 0.02,
#  'within days': 0.02,
#  'SIX': 0.015,
#  'n': 0.015,
#  'dont': 0.015,
#  'tomorrow': 0.015,
#  'Red': 0.015,
#  'pleased': 0.015,
#  'advise': 0.015,
#  'complimentary': 0.015,
#  'hear': 0.015,
#  'verify': 0.015,
#  'Account': 0.015,
#  'Expires': 0.015,
#  'Sunshine': 0.015,
#  'player': 0.015,
#  'soon': 0.015,
#  'career': 0.015,
#  'followed': 0.015,
#  'star': 0.015,
#  'SAM': 0.015,
#  'pence': 0.015,
#  'chart': 0.015,
#  'w': 0.015,
#  'newest': 0.015,
#  '11mths': 0.015,
#  'Germany': 0.015,
#  'via': 0.015,
#  'GBP': 0.015,
#  'Available': 0.015,
#  'MobilesDirect': 0.015,
#  'or2stoptxt': 0.015,
#  'competition': 0.015,
#  'heart': 0.015,
#  'EVE': 0.015,
#  'Ave': 0.015,
#  'post': 0.015,
#  'notice': 0.015,
#  'BOX95QU': 0.015,
#  'RING': 0.015,
#  'ladies': 0.015,
#  'kick': 0.015,
#  'Euro2004': 0.015,
#  'work': 0.015,
#  'subscribed': 0.015,
#  'life': 0.015,
#  'SUBPOLY': 0.015,
#  'supply': 0.015,
#  'records': 0.015,
#  'ASAP': 0.015,
#  'till': 0.015,
#  'Male': 0.015,
#  '5p': 0.015,
#  'Guess': 0.015,
#  'EURO': 0.015,
#  'FLOWER': 0.015,
#  'people': 0.015,
#  "U've": 0.015,
#  'receipt': 0.015,
#  'ans': 0.015,
#  'awaiting': 0.015,
#  'YESTERDAY': 0.015,
#  'many': 0.015,
#  'Energy': 0.015,
#  'choice': 0.015,
#  'textcomp': 0.015,
#  'cum': 0.015,
#  'Arsenal': 0.015,
#  'alone': 0.015,
#  '07xxxxxxxxx': 0.015,
#  'minMobsmoreLKPOBOX177HP51FL': 0.015,
#  'shortly': 0.015,
#  'ringtoneking': 0.015,
#  'stay': 0.015,
#  'bill': 0.015,
#  'Sorry': 0.015,
#  'ordered': 0.015,
#  'Hard': 0.015,
#  'biggest': 0.015,
#  'CHOSEN': 0.015,
#  'settings': 0.015,
#  'purchase': 0.015,
#  'right': 0.015,
#  'TsCs': 0.015,
#  'men': 0.015,
#  'med': 0.015,
#  '1000s': 0.015,
#  'heard': 0.015,
#  'U4': 0.015,
#  'rude': 0.015,
#  'weekend': 0.015,
#  'town': 0.015,
#  'Hol': 0.015,
#  'follow': 0.015,
#  'look': 0.015,
#  'Sept': 0.015,
#  '2stoptxt': 0.015,
#  'Super': 0.015,
#  'little': 0.015,
#  'VE': 0.015,
#  'crazy': 0.015,
#  'billed': 0.015,
#  'Save': 0.015,
#  'callback': 0.015,
#  'Valentine': 0.015,
#  'wallpaper': 0.015,
#  'FreeMsg Hey': 0.015,
#  'Valid hours': 0.015,
#  'special cinema': 0.015,
#  'cinema pass': 0.015,
#  'Suprman V': 0.015,
#  'V Matrix3': 0.015,
#  'Matrix3 StarWars3': 0.015,
#  'StarWars3 etc': 0.015,
#  '150pm Dont': 0.015,
#  'following recent': 0.015,
#  'recent review': 0.015,
#  'Code K52': 0.015,
#  'K52 Valid': 0.015,
#  'unredeemed Bonus': 0.015,
#  'Dogging locations': 0.015,
#  'Netcollex Ltd': 0.015,
#  'tc biz': 0.015,
#  'biz 2optout': 0.015,
#  '2optout 50gbp': 0.015,
#  '50gbp mtmsg18': 0.015,
#  '125gift guaranteed': 0.015,
#  'genuine HMV': 0.015,
#  'answer easy': 0.015,
#  '100percent real': 0.015,
#  'PHONE upgrade': 0.015,
#  'M26 3UZ': 0.015,
#  'CC HG': 0.015,
#  '4mths half': 0.015,
#  'Ldn WC1N3XX': 0.015,
#  'purpose Homeowners': 0.015,
#  'Homeowners Tenants': 0.015,
#  'previously refused': 0.015,
#  'CW25WX 150ppm': 0.015,
#  'terms conditions': 0.015,
#  'IBHltd LdnW15H': 0.015,
#  'LdnW15H 150p': 0.015,
#  'results daily': 0.015,
#  'e tlp': 0.015,
#  'tlp co': 0.015,
#  'City Break': 0.015,
#  'Summer Shopping': 0.015,
#  'SkilGme TsCs087147403231Winawk': 0.015,
#  'TsCs087147403231Winawk Age16': 0.015,
#  'Age16 50perWKsub': 0.015,
#  'COMUK CM2': 0.015,
#  'CM2 9AE': 0.015,
#  'alfie Moon': 0.015,
#  'Moon Children': 0.015,
#  'need song': 0.015,
#  'zed profit': 0.015,
#  'profit charity': 0.015,
#  'Cust care': 0.015,
#  'five pounds': 0.015,
#  'complimentary Ibiza': 0.015,
#  'BOX SK3': 0.015,
#  'SK3 8WP': 0.015,
#  'give away': 0.015,
#  'complimentary Tenerife': 0.015,
#  'BOX TCR': 0.015,
#  'TCR W1': 0.015,
#  'Dload polypH': 0.015,
#  'polypH music': 0.015,
#  'correct ans': 0.015,
#  'rcvd HG': 0.015,
#  'PocketBabe co': 0.015,
#  'new voicemail': 0.015,
#  'voicemail Please': 0.015,
#  'price Linerental': 0.015,
#  'LDN 18yrs': 0.015,
#  'ABTA complimentary': 0.015,
#  'SkillGame 1Winaweek': 0.015,
#  '1Winaweek age16': 0.015,
#  'age16 150ppermessSubscription': 0.015,
#  'ASAP BOX97N7QP': 0.015,
#  'BOX97N7QP 150ppm': 0.015,
#  'cross ntwk': 0.015,
#  'Halloween collection': 0.015,
#  'CARD SPOOK': 0.015,
#  'Nyt EC2A': 0.015,
#  'ec2a 3lp': 0.015,
#  '3lp msg': 0.015,
#  'phone DeliveredTomorrow': 0.015,
#  'nat rate': 0.015,
#  'wkly': 0.01,
#  'tkts': 0.01,
#  'rate': 0.01,
#  '08452810075over18': 0.01,
#  'Hey': 0.01,
#  'darling': 0.01,
#  'Tb': 0.01,
#  'rcv': 0.01,
#  'receivea': 0.01,
#  'KL341': 0.01,
#  'hours': 0.01,
#  'camera': 0.01,
#  'CSH11': 0.01,
#  'membership': 0.01,
#  'Jackpot': 0.01,
#  'dbuk': 0.01,
#  'LCCLTD': 0.01,
#  '4403LDNW1A7RW18': 0.01,
#  'XXXMobileMovieClub': 0.01,
#  'team': 0.01,
#  '4txt': 0.01,
#  'delivery': 0.01,
#  'Sptv': 0.01,
#  'pass': 0.01,
#  'following': 0.01,
#  'mob': 0.01,
#  'DIS': 0.01,
#  'Usher': 0.01,
#  'GENT': 0.01,
#  'Algarve': 0.01,
#  'Hardcore': 0.01,
#  'Randy': 0.01,
#  '08700621170150p': 0.01,
#  'arrange': 0.01,
#  'pls': 0.01,
#  'bootydelious': 0.01,
#  'goto': 0.01,
#  'unique': 0.01,
#  'enough': 0.01,
#  'August': 0.01,
#  'HORO': 0.01,
#  'sign': 0.01,
#  'quality': 0.01,
#  'charge': 0.01,
#  'sim': 0.01,
#  'Blind': 0.01,
#  'smart': 0.01,
#  'fixed': 0.01,
#  'prepayment': 0.01,
#  'lifetime': 0.01,
#  'balance': 0.01,
#  'Update_Now': 0.01,
#  'discount': 0.01,
#  '6months': 0.01,
#  'N9DX': 0.01,
#  'dating': 0.01,
#  'box334sk38ch': 0.01,
#  'txttowin': 0.01,
#  'lover': 0.01,
#  'joined': 0.01,
#  'ads': 0.01,
#  'July': 0.01,
#  'Dave': 0.01,
#  'b4280703': 0.01,
#  'mono': 0.01,
#  'Cha': 0.01,
#  'attempt': 0.01,
#  '24hrs': 0.01,
#  'web': 0.01,
#  '2stop': 0.01,
#  'call09050000327': 0.01,
#  '10ppm': 0.01,
#  'TEXTBUDDY': 0.01,
#  'gaytextbuddy': 0.01,
#  'expressoffer': 0.01,
#  'premium': 0.01,
#  'cool': 0.01,
#  'sue': 0.01,
#  'old': 0.01,
#  'FANTASTIC': 0.01,
#  'Email': 0.01,
#  'listen': 0.01,
#  'Nokia6650': 0.01,
#  'MTmsg': 0.01,
#  'Helpline': 0.01,
#  'around': 0.01,
#  'PREMIER': 0.01,
#  'Break': 0.01,
#  'community': 0.01,
#  'getstop': 0.01,
#  'PHP': 0.01,
#  'extra': 0.01,
#  'care': 0.01,
#  'discreet': 0.01,
#  'Virgin': 0.01,
#  'smsco': 0.01,
#  'Drop': 0.01,
#  'Travel': 0.01,
#  'mid': 0.01,
#  'stopsms': 0.01,
#  'Reminder': 0.01,
#  'gay': 0.01,
#  'cheaper': 0.01,
#  '8p': 0.01,
#  'peak': 0.01,
#  'lucky': 0.01,
#  'normal': 0.01,
#  'Lux': 0.01,
#  'company': 0.01,
#  'Filthy': 0.01,
#  'Somebody': 0.01,
#  'DATEBox1282EssexCM61XN': 0.01,
#  'LS15HB': 0.01,
#  'chatting': 0.01,
#  'EASTENDERS': 0.01,
#  'D': 0.01,
#  'TULIP': 0.01,
#  'LILY': 0.01,
#  'Lots': 0.01,
#  'C52': 0.01,
#  'information': 0.01,
#  'Bored': 0.01,
#  'SPEEDCHAT': 0.01,
#  'wish': 0.01,
#  'forget': 0.01,
#  '4fil': 0.01,
#  'WRC': 0.01,
#  'Rally': 0.01,
#  'Oz': 0.01,
#  'packs': 0.01,
#  'NOK': 0.01,
#  'ph': 0.01,
#  'Hungry': 0.01,
#  'feeling': 0.01,
#  'minmoremobsEMSPOBox45PO139WA': 0.01,
#  'videosound': 0.01,
#  'Lions': 0.01,
#  'lionp': 0.01,
#  'Harry': 0.01,
#  'FREE2DAY': 0.01,
#  '20p': 0.01,
#  'Bears': 0.01,
#  'linerental': 0.01,
#  'LF56': 0.01,
#  'condition': 0.01,
#  'CLAIRE': 0.01,
#  'costing': 0.01,
#  'LUCY': 0.01,
#  'Hubby': 0.01,
#  'Fri': 0.01,
#  'hotel': 0.01,
#  'leave': 0.01,
#  'JSco': 0.01,
#  'sing': 0.01,
#  'King': 0.01,
#  'SW73SS': 0.01,
#  'DRACULA': 0.01,
#  'Hlp': 0.01,
#  'movietrivia': 0.01,
#  'wiv': 0.01,
#  'married': 0.01,
#  'received': 0.01,
#  'connect': 0.01,
#  'WOW': 0.01,
#  'Boys': 0.01,
#  'IBH': 0.01,
#  'NOKIA6600': 0.01,
#  'BIG': 0.01,
#  'Mr': 0.01,
#  'Foley': 0.01,
#  'eye': 0.01,
#  'straight': 0.01,
#  'Wet': 0.01,
#  'upto': 0.01,
#  '12mths': 0.01,
#  'personal': 0.01,
#  'World': 0.01,
#  'enjoyed': 0.01,
#  'tones2you': 0.01,
#  'AOM': 0.01,
#  'GENDER': 0.01,
#  'Drinks': 0.01,
#  'Idew': 0.01,
#  'satisfy': 0.01,
#  'Home': 0.01,
#  'ref': 0.01}

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# 1. Tokenization
# 2. Remove Punctuations
# 3. Remove Stopwords
# 4. Remove Suffixes(Stemming)

# %%
sent_test = 'Hello Friends! How are you? I Like Python Programming.'
tokens1 = word_tokenize(sent_test)
tokens1
# Out:
# ['Hello',
#  'Friends',
#  '!',
#  'How',
#  'are',
#  'you',
#  '?',
#  'I',
#  'Like',
#  'Python',
#  'Programming',
#  '.']

# %%
# remove puncts
tokens2 = [word for word in tokens1 if word.isalnum()]
tokens2
# Out:
# ['Hello', 'Friends', 'How', 'are', 'you', 'I', 'Like', 'Python', 'Programming']

# %%
# remove stopwords
from nltk.corpus import stopwords
swords = stopwords.words('english')
tokens3 = [word for word in tokens2 if word.lower() not in swords]
tokens3
# Out:
# ['Hello', 'Friends', 'Like', 'Python', 'Programming']

# %%
# stemming/ suffixes removal
from nltk.stem import PorterStemmer
ps = PorterStemmer()
# remove the affixes
tokens4 = [ps.stem(word) for word in tokens3]
tokens4
# Out:
# ['hello', 'friend', 'like', 'python', 'program']

# %% [markdown]
# # Creating a function that applies all of the above steps

# %%
def data_cleaning(sent, lang='english', stemmer='porter'): # porter, lancaster, snowball
    from nltk.corpus import stopwords
    from nltk.stem import PorterStemmer, LancasterStemmer, SnowballStemmer 
    ps = PorterStemmer()
    ls = LancasterStemmer()
    ss = SnowballStemmer(language=lang)
    swords = stopwords.words(lang)
    if stemmer == 'porter':
        stem_obj = ps
    elif stemmer == 'lancaster':
        stem_obj = ls
    elif stemmer == 'snowball':
        stem_obj = ss
    tokens = [stem_obj.stem(word) for word in word_tokenize(sent) if word.lower() not in swords and word.isalpha()]    # ignoring numerical values
    return tokens

# %%
# testing the above function
tokens4 = data_cleaning(sent_test)
tokens4
# Out:
# ['hello', 'friend', 'like', 'python', 'program']

# %%
# cleaning all the messages in X
X.apply(data_cleaning) #args=('english','snowball')
# Out:
# 0       [go, jurong, point, crazi, avail, bugi, n, gre...
# 1                            [ok, lar, joke, wif, u, oni]
# 2       [free, entri, wkli, comp, win, fa, cup, final,...
# 3           [u, dun, say, earli, hor, u, c, alreadi, say]
# 4            [nah, think, goe, usf, live, around, though]
#                               ...
# 5567    [time, tri, contact, u, pound, prize, claim, e...
# 5568                       [ü, b, go, esplanad, fr, home]
# 5569                                [piti, mood, suggest]
# 5570    [guy, bitch, act, like, interest, buy, someth,...
# 5571                                   [rofl, true, name]
# Name: message, Length: 5572, dtype: object

# %% [markdown]
# ## Apply TF*IDF Vectorizer

# %%
tfidf = TfidfVectorizer(analyzer=data_cleaning)
x_new = tfidf.fit_transform(X)
x_new
# Out:
# <5572x5926 sparse matrix of type '<class 'numpy.float64'>'
# 	with 44423 stored elements in Compressed Sparse Row format>

# %%
x_new.shape
# Out:
# (5572, 5926)

# %%
tfidf.get_feature_names_out()
# Out:
# array(['aa', 'aah', 'aaniy', ..., 'zyada', 'é', 'ü'], dtype=object)

# %%
len(tfidf.get_feature_names_out())
# Out:
# 5926

# %%
### Cross-Validation
X_train, X_test, y_train, y_test = train_test_split(x_new, y, random_state=0) # default test_size=0.25

# %%
X_train.shape
# Out:
# (4179, 5926)

# %%
X_test.shape
# Out:
# (1393, 5926)

# %% [markdown]
# ### Build the SVM Model

# %%
svm = SVC(kernel='linear')
svm.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = svm.predict(X_test) # getting predicted values of the model

# %%
# performance evaluation
accuracy_score(y_test, y_pred)
# Out:
# 0.9827709978463748

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.98      1.00      0.99      1208
#         spam       0.99      0.88      0.93       185
#
#     accuracy                           0.98      1393
#    macro avg       0.98      0.94      0.96      1393
# weighted avg       0.98      0.98      0.98      1393

# %%
# confusion matrix
ConfusionMatrixDisplay.from_predictions(y_test, y_pred)

# %% [markdown]
# ### Prediction on unknown messages

# %%
# file: sample.csv
# https://mitu.co.in/dataset

# %%
with open('sample.csv', 'r') as f:
    sents = f.readlines()
sents
# Out:
# ['Ok lar i double check wif da hair dresser already he said wun cut v short. He said will cut until i look nice.\n',
#  'As a valued customer  I am pleased to advise you that following recent review of your Mob No. you are awarded with a ?1500 Bonus Prize  call 09066364589\n',
#  'Today is "song dedicated day.." Which song will u dedicate for me? Send this to all ur valuable frnds but first rply me...\n']

# %%
# transform to TF-IDF matrix using the previously defined tfidf transform class object
sample_new = tfidf.transform(pd.Series(sents))
sample_new
# Out:
# <3x5926 sparse matrix of type '<class 'numpy.float64'>'
# 	with 39 stored elements in Compressed Sparse Row format>

# %%
# predicting the class of the sentences
y_pred = svm.predict(sample_new)

# %%
y_pred # predicted classes of the sample data
# Out:
# array(['ham', 'spam', 'ham'], dtype=object)
